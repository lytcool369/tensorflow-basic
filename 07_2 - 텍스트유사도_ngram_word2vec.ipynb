# %% [markdown]
# ## 형태소 분석
#
# 형태소 분석(Morphoogical Analysis)는 문장을 *형태소* 라는 의미를 갖는 최소 단위로 분리하고 품사를 판별하는 작업이다. 형태소 분석은 기계번역, 텍스트 마이닝 등의 분야에서 사용한다.
#
# 영어문장의 형태소는 형태소 마다 띄어 쓰기를 하기 때문에 쉬울 수 있다. 예외소 *It's, don't* 등이 있는데 이것은 특정 단어를 *it is, do not* 으로 변환하므로 큰 문제가 되지 않는다.
#
# 아시아 계열의 문장은 노력이 필요하다. 대표적으로 문법 규칙에 의한 방법과 확률적 언어 모델을 사용하는 방법이 있다. 최근 확률적 언어 모델을 사용한 형태소 분석이 정밀도가 높고 많이 나오고 있다. 이 두 가지 모두 품사 사전과 문법 사전을 기반으로 대조해서 형태소를 분석한다.

# %% [markdown]
# ## N-gram 으로 유사도 구하기
#
# N-gram이란 텍스트에서 *이웃한 n개의 문자*를 의미한다. 서로 다른 2 문장을 N-gram으로 비교해 보면 출현하는 단어의 종류와 빈도를 확이할 수 있다. 이를 활용하면 논문 도용 등을 확인할 수 있다. 또한 코드의 라이센스 확인에도 활용할 수 있다.
#
# 다음 2 문장은 어느 정도 유사할까?
#
# - A. 오늘 강남에서 맛있는 스파게티를 먹었다.
# - B. 강남에서 먹었던 오늘의 스파게티는 맛있었다.
#
# ngram() 함수를 정의해 보자

# %%
def ngram(s, num):
    res = []
    slen = len(s) - num + 1
    for i in range(slen):
        ss = s[i:i+num]
        res.append(ss)
    return res

def diff_ngram(s1, s2, num):
    a = ngram(s1, num)
    b = ngram(s2, num)
    r = []
    cnt = 0
    for i in a:
        for j in b:
            if i == j:
                cnt +=1
                r.append(i)
    return cnt / len(a), r

# %%
a = '오늘 강남에서 맛있는 스파게티를 먹었다.'
b = '강남에서 먹었던 오늘의 스파게티는 맛있었다.'

# %% [markdown]
# 다음은 2글자씩 끊어 읽는다는 의미로 2-gram 이라고 한다.

# %%
ngram(a, 2)
# Out:
# ['오늘',
#  '늘 ',
#  ' 강',
#  '강남',
#  '남에',
#  '에서',
#  '서 ',
#  ' 맛',
#  '맛있',
#  '있는',
#  '는 ',
#  ' 스',
#  '스파',
#  '파게',
#  '게티',
#  '티를',
#  '를 ',
#  ' 먹',
#  '먹었',
#  '었다',
#  '다.']

# %% [markdown]
# 2-gram으로 비교하면?

# %%
r2, word2 = diff_ngram(a, b, 2)
print('2-gram:', r2, word2)
# Out:
# 2-gram: 0.7619047619047619 ['오늘', '강남', '남에', '에서', '서 ', ' 맛', '맛있', '는 ', ' 스', '스파', '파게', '게티', ' 먹', '먹었', '었다', '다.']

# %%
r3, word3 = diff_ngram(a, b, 3)
print('3-gram:', r3, word3)
# Out:
# 3-gram: 0.45 ['강남에', '남에서', '에서 ', ' 맛있', ' 스파', '스파게', '파게티', ' 먹었', '었다.']

# %% [markdown]
# 다음 문장은? 2그람으로 비교하면 74% 정도로, 문장 내용을 순서만 바꾼 것으로는 유사도가 높게 나온다.

# %%
a = '머신러닝은 매우 재미있는 기술이라 공부하고 있습니다'
b = '공부하면 재미있는 기술이라 머신러닝을 배우고 있습니다'

# %%
r2, word2 = diff_ngram(a, b, 2)
print('2-gram: ', r2, word2)
# Out:
# 2-gram:  0.7407407407407407 ['머신', '신러', '러닝', ' 재', '재미', '미있', '있는', '는 ', ' 기', '기술', '술이', '이라', '라 ', '공부', '부하', '고 ', ' 있', '있습', '습니', '니다']

# %%
r3, word3 = diff_ngram(a, b, 3)
print('3-gram: ', r3, word3)
# Out:
# 3-gram:  0.6153846153846154 ['머신러', '신러닝', ' 재미', '재미있', '미있는', '있는 ', '는 기', ' 기술', '기술이', '술이라', '이라 ', '공부하', '고 있', ' 있습', '있습니', '습니다']

# %%
# 비슷한 문장으로 2그람 유사도를 확인해보자
a = '본문과 관계 없는 내용이지만 마시멜로는 맛있습니다'
b = '마시멜로는 본문과 전혀 관계 없이 맛있습니다'

r2, word2 = diff_ngram(a, b, 2)
print('2-gram: ', r2, word2)
# Out:
# 2-gram:  0.6923076923076923 ['본문', '문과', '과 ', ' 관', '관계', '계 ', ' 없', '는 ', '마시', '시멜', '멜로', '로는', '는 ', ' 맛', '맛있', '있습', '습니', '니다']

# %%
# 관계없는 문장으로 2그람 유사도를 확인해보자
a = '파이썬 프로그래밍에서 중요한 것은 블록입니다'
b = '마시멜로는 본문과 전혀 관계 없이 맛있습니다'

r2, word2 = diff_ngram(a, b, 2)
print('2-gram: ', r2, word2)
# Out:
# 2-gram:  0.043478260869565216 ['니다']

# %% [markdown]
# N-gram을 이용하면 쉽게 문장 유사도를 확인할 수 있다. 이런 특징으로 문장 도용을 확인할 수 있고, 검색 엔진 등에서 웹 문서 유사도를 확인할 수 있는 다양성이 있다.
#
# ---

# %% [markdown]
# ## 한국어 형태소 분석 라이브러리
#
# 여러 형태소 분석 오픈소스 라이브러리가 있는ㄷ여기서는 KoNLPy(http://konlpy.org/ko/latest)를 이용하겠다. 이 KoNLPy를 사용하면 *한나눔*,*꼬꼬마*,*Komoran*,*MeCab*, *트위터* 등의 형태소 분석기를 이용할 수 있다.
#
# ### 설치
#
# konlpy 를 설치한다.
#
# ```
# pip install konlpy --user
# ```

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (0.5.2)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: tweepy>=3.7.0 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from konlpy) (3.8.0)
# Requirement already satisfied: colorama in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from konlpy) (0.4.3)
# Requirement already satisfied: lxml>=4.1.0 in /Users/qkboo/.local/lib/python3.7/site-packages (from konlpy) (4.2.5)
# Requirement already satisfied: numpy>=1.6 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from konlpy) (1.18.1)
# Requirement already satisfied: JPype1>=0.7.0 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from konlpy) (0.7.0)
# Requirement already satisfied: six>=1.10.0 in /Users/qkboo/.local/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: PySocks>=1.5.7 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.25.8)

# %% [markdown]
# 형태소 tag 클래스 밑에 형태소 분석기 클래스가 있다.
#  - Hannanum class
#  - Kkma class
#  - Komoran class
#  - Mecab class
#  - Okt clas
#
# 간단한 형태소 분석을 해보자,
#
# ### Okt class
#
# Open Korean Text [Okt class](http://konlpy.org/ko/latest/api/konlpy.tag/#okt-class) 는 Scala로 작성되서 한글 토큰나이저이다.
# > v0.5 이전에 Twitter class라고 했다
#
# ```
# class konlpy.tag._okt.Okt(jvmpath=None, max_heap_size=1024)
# ```

# %%
from konlpy.tag import Okt
okt = Okt()
malist = okt.pos("아버지 가방에 들어 가신다", norm=True, stem=True)
malist
# Out:
# [('아버지', 'Noun'),
#  ('가방', 'Noun'),
#  ('에', 'Josa'),
#  ('들다', 'Verb'),
#  ('가다', 'Verb')]

# %% [markdown]
# POS tagger. In contrast to other classes in this subpackage, this POS tagger doesn't have a flatten option, but has norm and stem options. Check the parameter list below.
#
# ```
# pos(phrase, norm=False, stem=False, join=False)
#  - norm -- If True, normalize tokens.
#  - stem -- If True, stem tokens.
#  - join -- If True, returns joined sets of morph and tag.
#
# ```
#
# `norm=True` 를 주면 *그래욬 ㅋㅋ?* 같은 단어를 *그래요* 로 정정해서 반환해 주고, stem 을 사용하면 *그렇다*라는 원형을 찾아 준다.
#
# KONLPy에 형태소 분석기 중 *아버지 가방에 들어가신다* 를 제대로 분석하는 것은 Kkma와 Okt 가 가능하다. Okt는 품사를 구분할 수 있고, Kkma는 품사가 NNG, JKM, VV, EPH, EFN 같이 나온다.

# %% [markdown]
# ## 출현 빈도 분석
#
# [KoNLPy는 말뭉치 파일(Corpus File)](http://konlpy.org/ko/latest/references/#corpora) 1) kolay: 한국 법률 말뭉치, 2) kobill: 국회의안 말뭉치을 제공하고 있다.
#
#  - http://konlpy.org/ko/latest/references/#corpora
#
# > [말뭉치를 이용한 관용구 사전의 의미 정보
# > (http://web.yonsei.ac.kr/bk21yskor/board/12/20070220194945637_권경일07.pdf)

# %%
from konlpy.corpus import kolaw
kolaw = kolaw.open('constitution.txt').read()
kolaw[:100]
# Out:
# '대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의'

# %%
from konlpy.tag import Okt

okt = Okt()
word_dic = {}
lines = kolaw.split('\n')
for line in lines:
    malist = okt.pos(line)
    for word in malist:
        if word[1] == 'Noun':
            if not (word[0] in word_dic):
                word_dic[word[0]] = 0
            word_dic[word[0]] += 1
#빈도
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, count in keys[:50]:
    print("{0}({1}) ".format(word, count), end="")
print()
# Out:
# 제(175) 법률(127) 정(89) 수(88) 대통령(83) 국가(73) 국회(68) 국민(61) 관(58) 때(55) 헌법(53) 그(47) 이(38) 모든(37) 바(37) 위(36) 기타(26) 및(25) 사항(23) 권리(21) 의원(21) 안(21) 정부(20) 선거(20) 자유(20) 임명(20) 직무(19) 국무총리(19) 경제(18) 조직(18) 의무(18) 국회의원(18) 임기(18) 경우(17) 이상(17) 공무원(17) 국무위원(17) 대법원(17) 의결(17) 범위(16) 장(15) 법관(15) 재적(14) 보호(14) 관리(14) 항의(14) 헌법재판소(14) 정책(14) 회의(14) 정당(14)

# %% [markdown]
# ---
#
# # Word2Vec으로 문장을 벡터로 변환하기
#
# 분리한 단어들 사이의 연관을 분석하기 위해서는 단어와 단어를 벡터로 전환해 유사도를 분석해야 한다.
#
#     6-2-1. Word2Vec
#     6-2-2. Gensim 설치
#     6-2-3. Gensim의 Word2Vec으로 "토지"를 읽어보기
#     6-2-4. 위키피디아 한국어 버전을 사전으로 사용해보기
#     6-2-5. 위키피디아 데이터로 놀아보기

# %% [markdown]
# ## Word2Vec
#
# Word2Vec은 문자 내부 단어를 벡터로 변환해준다. 단여 연결을 기반으로 연관성을 벡터로 만들어 준다. 벡터를 사용해 단어의 의미를 파악할 수 있다.
#
# Word2Vec을 구현하는 도구는 많은데 파이썬으로 실행할 수 있는 Gensim 을 사용해 보자, Gensim은 자연어를 처리하는 라이브러리이다. 이 중에 Word2vec 기능이 있다.
#
#  - https://radimrehurek.com/gensim/
#
# 설치는
#
# ```
# pip install --upgrade gensim --user
# ```

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-3.8.3-cp37-cp37m-macosx_10_9_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 1.2 MB/s eta 0:00:01    |████▋                           | 3.5 MB 741 kB/s eta 0:00:28
# Collecting smart-open>=1.8.1
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.0 in /Users/qkboo/.local/lib/python3.7/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from gensim) (1.18.1)
# Requirement already satisfied: requests in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/qkboo/.pyenv/versions/anaconda3-5.3.1/envs/deep_learning/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2.9)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=6e44a69eba3111873ec753ff7ca7b918fb788e4fca561cfec6ec2e3acb9f6056
#   Stored in directory: /Users/qkboo/Library/Caches/pip/wheels/83/a6/12/bf3c1a667bde4251be5b7a3368b2d604c9af2105b5c1cb1870
# Successfully built smart-open
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-3.8.3 smart-open-3.0.0

# %% [markdown]
# ## Gensim의 Word2Vec으로 읽어보기

# %%
from konlpy.tag import Okt
from konlpy.corpus import kolaw
from gensim.models import word2vec

kolaw = kolaw.open('constitution.txt').read()

# %%
okt = Okt()
results = []
lines = kolaw.split('\n')
for line in lines:
    #형태소분석: 단어기본형 사용.
    malist = okt.pos(line, norm=True, stem=True)
    r = []
    for word in malist:
        #어미/조사/구두점 등은 대상에서 제외
        if not word[1] in ['Josa', 'Eomi', 'Punctuation']:
            r.append(word[0])
    rl = (" ".join(r)).strip()
    results.append(rl)
    print(rl)
#파일로 출력하기
wakati_file = 'data/kolaw.wakati'
with open(wakati_file, 'w', encoding='utf-8') as fp:
    fp.write('\n'.join(results))
# word2vec 모델
data = word2vec.LineSentence(wakati_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)
model.save('data/kolaw.model')
print('OK')
# Out:
# 대한민국 헌법
#
# 유구 역사 전통 빛나다 우리 대 한 국민 3 1 운동 건립 되다 대한민국 임시정부 법 통과 불의 항거 4 19 민주 이념 계승 조국 민주 개혁 평화 적 통일 사명 입 각하 정의 인도 동포 애 로써 민족 단결 공고 히 하다 모든 사회 적 폐습 불의 타파 하다 자율 조화 바탕 자유민주 적 기 본 질서 더욱 확고하다 하다 정치 경제 사회 문화 모든 영역 있다 각인 기회 균등하다 하다 능력 최고 도로 발휘 하다 하다 자유 권리 따르다 책임 의무 완수 하다 하다 안 국민 생활 균등하다 향상 기하 밖 항구 적 세계 평화 인류 공영 이바지 함 우리 들 우리 들 자손 안전 자유 행복 영원하다 확보 하다 것 다짐 하다 1948년 7월 12일 에 제정 되다 8 차 걸치다 개정 되다 헌법 이제 국회 의결 거치다 국민투표 의하다 개정 하다
#
# 제 1 장 총 강
# 제 1조 ① 대한민국 민주공화국
# ② 대한민국 주권 국민 있다 모든 권력 국민 나오다
# 제 2조 ① 대한민국 국민 되다 요건 법률 정 하다
# ② 국가 법률 정 하다 바 의하다 재외국민 보호 하다 의무 지다
# 제 3조 대한민국 영토 한반도 그 부속 도서 하다
# 제 4조 대한민국 통일 지향 하다 자유민주 적 기 본 질서 입각 평화 적 통일 정책 수립 이르다 추진 다
# 제 5조 ① 대한민국 국제 평화 유지 노력 침략 적 전쟁 부인 하다
# ② 국군 국가 안전보장 국토 방위 신성하다 의무 수행 함 사명 하다 그 정치 적 중립성 준수 되다
# 제 6조 ① 헌법 의하다 체결 공포 되다 조약 일반 적 승인 되다 국제 법규 국내법 같다 효력 가지다
# ② 외국인 국제 법 조약 정 하다 바 의하다 그 지위 보장 되다
# 제 7조 ① 공무원 국민 전체 대한 봉사자 국민 대하 책임 지다
# ② 공무원 신분 정치 적 중립성 법률 정 하다 바 의하다 보장 되다
# 제 8조 ① 정당 설립 자유 복수정당제 보장 되다
# ② 정당 그 목적 조직 활동 민주 적다 하다 국민 정치 적 의사 형성 참여 하다 필요하다 조직 가다 하다
# ③ 정당 법률 정 하다 바 의하다 국가 보호 받다 국가 법률 정 하다 바 의하다 정당 운영 필요하다 자금 보조 하다 수 있다
# ④ 정당 목적 활동 민주 적 기 본 질서 위배 되다 때 정부 헌법재판소 그 해산 제소 하다 수 있다 정당 헌법재판소 심판 의하다 해산 되다
# 제 9조 국가 전통문화 계승 발전 민족 문화 창달 노력 하다 하다
#
# 제 2 장 국민 권리 의무
# 제 10조 모든 국민 인간 존엄 가치 가지 행복 추구 하다 권리 가지다 국가 개인 가지다 불가침 기본 적 인권 확인 이르다 보장 하다 의무 지다
# 제 11조 ① 모든 국민 법 앞 평등하다 누구 성별 종교 또는 사회 적 신분 의하다 정치 적 경제 적 사회 적 문화 적 생활 모든 영역 있다 차별 받다 아니다 하다
# ② 사회 적 특수 계급 제도 인정 되다 아니다 어떠하다 형태 도 이르다 창설 하다 수 없다
# ③ 훈장 등 영전 이르다 받다 자 효력 있다 어떠하다 특권 이 따르다 아니다 하다
# 제 12조 ① 모든 국민 신체 자유 가지다 누구 법률 의하다 아니다 체포 구속 압수 수색 또는 심문 받다 아니다 법률 적법하다 절차 의하다 아니다 처벌 보안처분 또는 강제 노역 받다 아니다 하다
# ② 모든 국민 고문 받다 아니다 형사 상 자기 불리하다 진술 강요 당하다 아니다 하다
# ③ 체포 구속 압수 또는 수색 하다 때 적법하다 절차 따르다 검사 신청 의하다 법관 발부 영장 제시 하다 하다 다만 현행범인 경우 장기 3년 이상 형 해당 하다 죄 범 도피 또는 증거 멸 염려 있다 때 사후 영장 청구 하다 수 있다
# ④ 누구 체포 또는 구속 당한 때 즉시 변호인 조력 받다 권리 가지다 다만 형사 피고인 스스로 변호인 구 하다 수 없다 때 법률 정 하다 바 의하다 국가 변호인 붙이다
# ⑤ 누구 체포 또는 구속 이유 변호인 조력 받다 권리 있다 음 고지 받다 아니다 체포 또는 구속 당하다 아니다 하다 체포 또는 구속 당한 자의 가족 등 법률 정 하다 자 그 이유 일시 장소 지체 없이 통지 되어다 하다
# ⑥ 누구 체포 또는 구속 당한 때 적 부의 심사 법원 청구 하다 권리 가지다
# ⑦ 피고인 자백 고문 폭행 협박 구속 부당하다 장기 화 또는 기 망 기타 방법 의하다 자의 진술 되다 것 아니다 인정 되다 때 또는 정식 재판 있다 피고인 자백 그 불리하다 유일하다 증거 일 때 이르다 유죄 증거 사다 이르다 이유 처벌 하다 수 없다
# 제 13조 ① 모든 국민 행위 시 법률 의하다 범죄 구성 하다 아니다 행위 소 추 되다 아니다 동일하다 범죄 대하 거듭 처벌 받다 아니다 하다
# ② 모든 국민 소급입법 의하다 참정권 제한 받다 재산권 박탈 당하다 아니다 하다
# ③ 모든 국민 자기 행위 아니다 친족 행위 인하다 불이익 처우 받다 아니다 하다
# 제 14조 모든 국민 거주 이전 자유 가지다
# 제 15조 모든 국민 직업 선택 자유 가지다
# 제 16조 모든 국민 주거 자유 침해 받다 아니다 하다 주거 대한 압수 수색 하다 때 검사 신청 의하다 법관 발부 영장 제시 하다 하다
# 제 17조 모든 국민 사생활 비밀 자유 침해 받다 아니다 하다
# 제 18조 모든 국민 통신 비밀 침해 받다 아니다 하다
# 제 19조 모든 국민 양심 자유 가지다
# 제 20조 ① 모든 국민 종교 자유 가지다
# ② 국교 인정 되다 아니다 종교 정치 분리 되다
# 제 21조 ① 모든 국민 언론 출판 자유 집회 결사 자유 가지다
# ② 언론 출판 대한 허가 검열 집회 결사 대한 허가 인정 되다 아니다 하다
# ③ 통신 방송 시설 기준 신문 기능 보장 하다 위 하다 필요하다 사항 법률 정 하다
# ④ 언론 출판 타인 명예 권리 또는 공중도덕 사회 윤리 침해 하다 서다 아니다 되다 언론 출판 타인 명예 권리 침해 때 피해자 이 대한 피해 배상 청구 하다 수 있다
# 제 22조 ① 모든 국민 학문 예술 자유 가지다
# ② 저작자 발명가 과학기술 자 예술가 권리 법률 로써 보호 하다
# 제 23조 ① 모든 국민 재산권 보장 되다 그 내용 한계 법률 정 하다
# ② 재산권 행사 공공 복리 적합하다 하다 하다
# ③ 공공필요 의하다 재산권 수용 사용 또는 제한 및 그 대한 보상 법률 로써 하 되다 정당하다 보상 지급 하다 하다
# 제 24조 모든 국민 법률 정 하다 바 의하다 선거권 가지다
# 제 25조 모든 국민 법률 정 하다 바 의하다 공무 담임 권 가지다
# 제 26조 ① 모든 국민 법률 정 하다 바 의하다 국가 기관 문서 청원 하다 권리 가지다
# ② 국가 청원 대하 심사 하다 의무 지다
# 제 27조 ① 모든 국민 헌법 법률 정 법관 의하다 법률 의하다 재판 받다 권리 가지다
# ② 군인 또는 군무원 아니다 국민 대한민국 영역 안 중대하다 군사 상 기밀 초병 초소 유독 음식물 공급 포로 군용 물 관 죄 중 법률 정 경우 비상계엄 선포 되다 경우 제외 군사법원 재판 받다 아니다 하다
# ⑥ 국가 재해 예방 그 위험 국민 보호 하다 위 하다 노력 하다 하다
# 제 35조 ① 모든 국민 건강하다 쾌적하다 환경 생활 하다 권리 가지 국가 국민 환경보전 위 하다 노력 하다 하다
# ② 환경권 내용 행사 관 하다 법률 정 하다
# ③ 국가 주택 개발 정책 등 통 하다 모든 국민 쾌적하다 주거 생활 하다 수 있다 노력 하다 하다
# 제 36조 ① 혼인 가족 생활 개인 존엄 양성 평등 기초 성립 되다 유지 되어다 하다 국가 이르다 보장 하다
# ② 국가 모성 보호 위 하다 노력 하다 하다
# ③ 모든 국민 보건 관 하다 국가 보호 받다
# 제 37조 ① 국민 자유 권리 헌법 열거 되다 아니다 이유 경시 되다 아니다 하다
# ② 국민 모든 자유 권리 국가 안전보장 질서 유지 또는 공공 복리 위 하다 필요하다 경우 하다 법률 로써 제한 하다 수 있다 제한 하다 경우 자유 권리 본질 적 내용 침해 하다 수 없다
# 제 38조 모든 국민 법률 정 하다 바 의하다 납세 의무 지다
# 제 39조 ① 모든 국민 법률 정 하다 바 의하다 국방 의무 지다
# ② 누구 병역의무 이행 인하다 불이익 처우 받다 아니다 하다
#
# 제 3 장 국회
# 제 40조 입법권 국회 속 하다
# 제 41조 ① 국회 국민 보통 평등 직접 비밀선거 의하다 선출 되다 국회의원 구성 다
# ② 국회의원 수 법률 정 하 되다 200 인 이상 하다
# ③ 국회의원 선거구 비례대표제 기타 선거 관 사항 법률 정 하다
# 제 42조 국회의원 임기 4년 으로 하다
# 제 43조 국회의원 법률 정 하다 직 겸 하다 수 없다
# 제 44조 ① 국회의원 현행범인 경우 제외 회 기 중 국회 동의 없이 체포 또는 구금 되다 아니다 하다
# ② 국회의원 회 기전 체포 또는 구금 되다 때 현행범인 아니다 하다 국회 요구 있다 회 기 중 석방 되다
# 제 45조 국회의원 국회 직무 상 행 발언 표결 관 하다 국회 외 책임 지지 아니다 하다
# 제 46조 ① 국회의원 청렴 의무 있다
# ② 국회의원 국가 이익 우선하다 양심 따르다 직무 행 하다
# ③ 국회의원 그 지위 남용 하다 국가 공공 단체 또는 기업체 계약 그 처분 의하다 재산 상의 권리 이익 또는 직위 취득 하 거나 타인 위 하다 그 취득 알선 하다 수 없다
# 제 47조 ① 국회 정기회 법률 정 하다 바 의하다 매년 1회 집회 되다 국회 임시회 대통령 또는 국회 재적 의원 4분 의 1 이상 요구 의하다 집회 되다
# ② 정기회 회 기다 100일 을 임시회 회 기다 30일 을 초과 하다 수 없다
# ③ 대통령 임시회 집회 요구 하다 때 기간 집회 요구 이유 명시 하다 하다
# 제 48조 국회 의장 1 인과 부의 장 2 인 선출 하다
# 제 49조 국회 헌법 또는 법률 특별하다 규정 없다 하다 재적 의원 과반수 출석 출석 의원 과반수 찬성 의결 하다 가부 동 수인 때 부결 되다 것 보다
# 제 50조 ① 국회 회의 공개 다 다만 출석 의원 과반수 찬성 있다 의장 국가 안전보장 위 하다 필요하다 인정 하다 때 공개 하다 아니다 하다 수 있다
# ② 공개 하다 아니다 회의 내용 공표 관 하다 법률 정 하다 바 의하다
# 제 51조 국회 제출 되다 법률 안 기타 의안 회 기 중 의결 되다 못 이유 폐기 되다 아니다 하다 다만 국회의원 임기 만료 되다 때 그러하다 아니다
# 제 52조 국회의원 정부 법률 안 제출 하다 수 있다
# 제 53조 ① 국회 의결 되다 법률 안다 정부 이송 되어다 15일 이내 대통령 공포 다
# ② 법률 안 이의 있다 때 대통령 제 1 항의 기간 내 이의 를 붙이다 국회 환부 그 재의 요구 하다 수 있다 국회 폐회 중 또한 같다
# ③ 대통령 법률 안 일부 대하 또는 법률 안 수정 하다 재의 요구 하다 수 없다
# ④ 재의 요구 있다 때 국회 재의 붙이 재적 의원 과반수 출석 출석 의원 3분 의 2 이상 찬성 전과 같다 의결 하다 그 법률 안다 법률 로서 확정 되다
# ⑤ 대통령 제 1 항의 기간 내 공포 재의 요구 하다 아니다 때 그 법률 안다 법률 로서 확정 되다
# ⑥ 대통령 제 4 항 제 5 항의 규정 의하다 확정 되다 법률 지체 없이 공포 하다 하다 제 5 항 의하다 법률 확정 되다 후 또는 제 4 항 의하다 확정 법률 정부 이송 되다 후 5일 이내 대통령 공포 하다 아니다 하다 때 국회의장 이르다 공포 다
# ⑦ 법률 특별하다 규정 없다 하다 공포 날로 20일 을 경과 함 효력 발생 하다
# 제 54조 ① 국회 국가 예산안 심의 확정 하다
# ② 정부 회계 연도 예산안 편성 하다 회계 연도 개시 90일 전까지 국회 제출 국회 회계 연도 개시 30일 전까지 이르다 의결 하다 하다
# ③ 새롭다 회계 연도 개시 되다 때 예산안 의결 되다 못 때 정부 국회 예산안 의결 되다 때 다음 목적 위 경비 전 년도 예산 준 하다 집행 하다 수 있다
# 1 헌법 법률 의하다 설치 되다 기관 또는 시설 유지 운영
# 2 법률상 지출 의무 이행
# 3 이미 예산 승인 되다 사업 계속
# 제 55조 ① 하다 회계 연도 넘다 계속 하다 지출 하다 필요 있다 때 정부 연한 정 하다 계속 비 로서 국회 의결 얻다 하다
# ② 예 비비 총 액 국회 의결 얻다 하다 예 비비 지출 차기 국회 승인 얻다 하다
# 제 56조 정부 예산 변경 가하다 필요 있다 때 추가경정예산 안 편성 하다 국회 제출 하다 수 있다
# 제 57조 국회 정부 동의 없이 정부 제출 지출 예산 각항 금액 증가 하 거나 새 비목 설치 하다 수 없다
# 제 58조 국채 모집 하 거나 예산 외 국가 부담 되다 계약 체결 하다 하다 때 정부 미리 국회 의결 얻다 하다
# 제 59조 조세 종목 세율 법률 정 하다
# 제 60조 ① 국회 상호 원조 또는 안전보장 관 조약 중요하다 국제 조직 관 조약 우호 통상 항해 조약 주권 제약 관 조약 강화조약 국가 국민 중대하다 재정 적 부담 지우다 조약 또는 입법 사항 관 조약 체결 비준 대한 동의 권 가지다
# ② 국회 선전포고 국군 외국 파견 또는 외국 군대 대한민국 영역 안 주류 대한 동의 권 가지다
# 제 61조 ① 국회 국정 감사 하 거나 특정하다 국정 사안 대하 조사 하다 수 있다 이 필요하다 서류 제출 또는 증인 출석 증언 의견 진술 요구 하다 수 있다
# ② 국민 경제 자 문 회의 조직 직무 범위 기타 필요하다 사항 법률 정 하다
# 제 3 관 행정각부
# 제 94조 행정각부 장 국무위원 중 국무총리 제청 대통령 임명 하다
# 제 95조 국무총리 또는 행정각부 장 소관 사무 관 하다 법률 대통령령 위임 또는 직권 총리 령 또는 부령 발 하다 수 있다
# 제 96조 행정각부 설치 조직 직무 범위 법률 정 하다
# 제 4 관 감사원
# 제 97조 국가 세입 세 추다 결산 국가 및 법률 정 단체 회계 검사 행정기관 및 공무원 직무 관 감찰 하다 위 하다 대통령 소속 하 감사원 두다
# 제 98조 ① 감사원 원장 포함 5 인 이상 11 인 이하 감사 위원 구성 다
# ② 원장 국회 동의 얻다 대통령 임명 그 임기 4년 으로 하다 1 차 하다 중임 하다 수 있다
# ③ 감사 위원 원장 제청 대통령 임명 그 임기 4년 으로 하다 1 차 하다 중임 하다 수 있다
# 제 99조 감사원 세입 세 추다 결산 매년 검사 하다 대통령 차 년도 국회 그 결과 보고 하다 하다
# 제 100조 감사원 조직 직무 범위 감사 위원 자격 감사 대상 공무원 범위 기타 필요하다 사항 법률 정 하다
#
# 제 5 장 법원
# 제 101조 ① 사법권 법관 구성 되다 법원 속 하다
# ② 법원 최고법원 대법원 각 급 법원 조직 되다
# ③ 법관 자격 법률 정 하다
# 제 102조 ① 대법원 부르다 둘 수 있다
# ② 대법원 대법관 두다 다만 법률 정 하다 바 의하다 대법관 아니다 법관 둘 수 있다
# ③ 대법원 각 급 법원 조직 법률 정 하다
# 제 103조 법관 헌법 법률 의하다 그 양심 따르다 독립 하다 심판 하다
# 제 104조 ① 대법원 장 국회 동의 얻다 대통령 임명 하다
# ② 대법관 대법원 장 제청 국회 동의 얻다 대통령 임명 하다
# ③ 대법원 장 대법관 아니다 법관 대법관 회의 동의 얻다 대법원 장이 임명 하다
# 제 105조 ① 대법원 장 임기 6년 으로 하다 중임 하다 수 없다
# ② 대법관 임기 6년 으로 하다 법률 정 하다 바 의하다 연 임 하다 수 있다
# ③ 대법원 장 대법관 아니다 법관 임기 10년 으로 하다 법률 정 하다 바 의하다 연 임 하다 수 있다
# ④ 법관 정년 법률 정 하다
# 제 106조 ① 법관 탄핵 또는 금고 이상 형 선고 의하다 아니다 파면 되다 아니다 징계처분 의하다 아니다 정직 감봉 기타 불리하다 처분 받다 아니다 하다
# ② 법관 중대하다 심신 상의 장해 직무 수행 하다 수 없다 때 법률 정 하다 바 의하다 퇴직 하다 하다 수 있다
# 제 107조 ① 법률 헌법 위반 되다 여부 재판 전제 되다 경우 법원 헌법재판소 제청 하다 그 심판 의하다 재판 하다
# ② 명령 규칙 또는 처분 헌법 법률 위반 되다 여부 재판 전제 되다 경우 대법원 이르다 최종 적 심사 하다 권한 가지다
# ③ 재판 전심 절차 로서 행정심판 하다 수 있다 행정심판 절차 법률 정 하 되다 사법 절차 준용 되어다 하다
# 제 108조 대법원 법률 저촉 되다 아니다 범위 안 소송 관 절차 법원 내부 규율 사무 처리 관 규칙 제정 하다 수 있다
# 제 109조 재판 심리 판결 공개 다 다만 심리 국가 안전보장 또는 안녕 질서 방 하다 선량하다 풍속 해 하다 염려 있다 때 법원 결정 공개 하다 아니다 하다 수 있다
# 제 110조 ① 군사재판 관할 하다 위 하다 특별법 원 군사법원 둘 수 있다
# ② 군사법원 상고 심다 대법원 관할 하다
# ③ 군사법원 조직 권한 및 재판관 자격 법률 정 하다
# ④ 비상계엄 하의 군사재판 군인 군무원 범죄 군사 관 간첩죄 경우 초병 초소 유독 음식물 공급 포로 관 죄 중 법률 정 경우 하다 단심 하다 수 있다 다만 사형 선고 경우 그러하다 아니다
#
# 제 6 장 헌법재판소
# 제 111조 ① 헌법재판소 다음 사항 관장 하다
# 1 법원 제청 의하다 법률 위 헌 여부 심판
# 2 탄핵 심판
# 3 정당 해산 심판
# 4 국가 기관 상호 간 국가 기관 지방자치단체 간 및 지방자치단체 상호 간 권한 쟁의 관 심판
# 5 법률 정 하다 헌법소원 관 심판
# ② 헌법재판소 법관 자격 가지다 9 인의 재판관 구성 하다 재판관 대통령 임명 하다
# ③ 제 2 항의 재판관 중 3 인 국회 선출 하다 자르다 3 인 대법원 장이 지명 하다 자르다 임명 하다
# ④ 헌법재판소 장 국회 동의 얻다 재판관 중 대통령 임명 하다
# 제 112조 ① 헌법재판소 재판관 임기 6년 으로 하다 법률 정 하다 바 의하다 연 임 하다 수 있다
# ② 헌법재판소 재판관 정당 가입 하 거나 정치 관여 하다 수 없다
# ③ 헌법재판소 재판관 탄핵 또는 금고 이상 형 선고 의하다 아니다 파면 되다 아니다 하다
# 제 113조 ① 헌법재판소 법률 위 헌 결정 탄핵 결정 정당 해산 결정 또는 헌법소원 관 인용 결정 하다 때 재판관 6 인 이상 찬성 있다 하다
# ② 헌법재판소 법률 저촉 되다 아니다 범위 안 심판 관 절차 내부 규율 사무 처리 관 규칙 제정 하다 수 있다
# ③ 헌법재판소 조직 운영 기타 필요하다 사항 법률 정 하다
#
# 제 7 장 선거 관리
# 제 114조 ① 선거 국민투표 공정하다 관리 및 정당 관 사무 처리 하다 위 하다 선거 관리 위원회 두다
# ② 중앙 선거 관리 위원회 대통령 임명 하다 3 인 국회 선출 하다 3 인과 대법원 장이 지명 하다 3 인의 위원 구성 다 위원장 위원 중 호선 하다
# ③ 위원 임기 6년 으로 하다
# ④ 위원 정당 가입 하 거나 정치 관여 하다 수 없다
# ⑤ 위원 탄핵 또는 금고 이상 형 선고 의하다 아니다 파면 되다 아니다 하다
# ⑥ 중앙 선거 관리 위원회 법령 범위 안 선거 관리 국민투표 관리 또는 정당 사무 관 규칙 제정 하다 수 있다 법률 저촉 되다 아니다 범위 안 내부 규율 관 규칙 제정 하다 수 있다
# ⑦ 각 급 선거 관리 위원회 조직 직무 범위 기타 필요하다 사항 법률 정 하다
# 제 115조 ① 각 급 선거 관리 위원회 선거인명부 작성 등 선거 사무 국민투표 사무 관 하다 관계 행정기관 필요하다 지시 하다 수 있다
# ② 제 1 항의 지시 받다 당하다 행정기관 이 응 하다 하다
# 제 116조 ① 선거운동 각 급 선거 관리 위원회 관리 하 법률 정 하다 범위 안 하 되다 균등하다 기회 보장 되어다 하다
# ② 선거 관 경비 법률 정 하다 경우 제외 정당 또는 후보자 부담 시키다 수 없다
#
# 제 8 장 지방자치
# 제 117조 ① 지방자치단체 주민 복리 관 사무 처리 재산 관리 하다 법령 범위 안 자치 관 규정 제정 하다 수 있다
# ② 지방자치단체 종류 법률 정 하다
# 제 118조 ① 지방자치단체 의회 두다
# ② 지방의회 조직 권한 의원 선거 지방자치단체 장의 선임 방법 기타 지방자치단체 조직 운영 관 사항 법률 정 하다
#
# 제 9 장 경제
# 제 119조 ① 대한민국 경 제 질서 개인 기업 경제 상의 자유 창의 존중 함 기본 하다
# ② 국가 균형 있다 국민 경제 성장 및 안정 적정하다 소득 분배 유지 시장 지배 경제력 남용 방지 하다 경 제 주체 간 조화 통한 경제 민주화 위 하다 경제 관 규제 조정 하다 수 있다
# 제 120조 ① 광물 기타 중요하다 지하자원 수산 자원 수력 경제 상 이용 하다 수 있다 자연력 법률 정 하다 바 의하다 일정하다 기간 그 채취 개발 또는 이용 특허 하다 수 있다
# ② 국토 자원 국가 보호 받다 국가 그 균형 있다 개발 이용 위 하다 필요하다 계획 수립 하다
# 제 121조 ① 국가 농지 관 하다 경 자유 전의 원칙 달성 되다 수 있다 노력 하다 하다 농지 소 작 제도 금지 되다
# ② 농업 생산 성의 제 고 농지 합리 적 이용 위 하 거나 불가피하다 사정 발생 하다 농지 임대차 위탁 경영 법률 정 하다 바 의하다 인정 되다
# 제 122조 국가 국민 모두 생산 및 생활 기반 되다 국토 효율 적 균형 있다 이용 개발 보전 위 하다 법률 정 하다 바 의하다 그 관 필요하다 제한 의무 과 하다 수 있다
# 제 123조 ① 국가 농업 및 어업 보호 육성 하다 위 하다 농 어촌 종합 개발 그 지원 등 필요하다 계획 수립 시행 하다 하다
# ② 국가 지역 간 균형 있다 발전 위 하다 지역 경제 육성 하다 의무 지다
# ③ 국가 중소기업 보호 육성 하다 하다
# ④ 국가 농수산 물의 수급 균형 유통 구조 개선 노력 하다 가격 안정 도 모함 농 어민 이익 보호 하다
# ⑤ 국가 농 어민 중소기업 자 조 조직 육성 하다 하다 그 자율 적 활동 발전 보장 하다
# 제 124조 국가 건전하다 소비 행위 계 도하 생산품 품질 향상 촉구 하다 위 소비자보호 운동 법률 정 하다 바 의하다 보장 하다
# 제 125조 국가 대외 무역 육성 하다 이르다 규제 조정 하다 수 있다
# 제 126조 국방 상 또는 국민 경제 상 기다 절 필요 인하다 법률 정 하다 경우 제외 사 영 기업 국유 또는 공유 이 전하 거나 그 경영 통제 또는 관리 하다 수 없다
# 제 127조 ① 국가 과학기술 혁신 정보 및 인력 개발 통 하다 국민 경제 발전 노력 하다 하다
# ② 국가 국가 표준 제도 확립 하다
# ③ 대통령 제 1 항의 목적 달성 하다 위 하다 필요하다 자문 기구 둘 수 있다
# 제 10 장 헌법 개정
# 제 128조 ① 헌법 개 정은 국회 재적 의원 과반수 또는 대통령 발의 제안 되다
# ② 대통령 임기 연장 또는 중임 변경 위 헌법 개 정은 그 헌법 개정 제안 당시 대통령 대하 여 효력 없다
# 제 129조 제안 되다 헌법 개정안 대통령 20일 이상 기간 이르다 공고 하다 하다
# 제 130조 ① 국회 헌법 개정안 공고 되다 날로 60일 이내 의결 하다 하다 국회 의결 재적 의원 3분 의 2 이상 찬성 얻다 하다
# ② 헌법 개정안 국회 의결 후 30일 이내 국민투표 붙이다 국회의원 선거권 자 과반수 투표 투표 자 과반수 찬성 얻다 하다
# ③ 헌법 개정안 제 2 항의 찬성 얻다 때 헌법 개 정은 확정 되다 대통령 즉시 이르다 공포 하다 하다
#
# 펼치다 부칙 헌법 제 10 호 1987.10 29 부칙 보기
#
# 제 1조 이 헌법 1988년 2월 25일 부터 시행 하다 다만 이 헌법 시행 하다 위 하다 필요하다 법률 제정 개정 이 헌법 의하다 대통령 및 국회의원 선거 기타 이 헌법 시행 관 준비 이 헌법 시행 전 하다 수 있다
# 제 2조 ① 이 헌법 의하다 최초 대통령선거 이 헌법 시행일 40일 전 실시 하다
# ② 이 헌법 의하다 최초 대통령 임기 이 헌법 시행일 로부터 개시 다
# 제 3조 ① 이 헌법 의하다 최초 국회의원선거 이 헌법 공포일 로부터 6월 이내 실시 하다 이 헌법 의하다 선출 되다 최초 국회의원 임기 국회의원선거 후 이 헌법 의하다 국회 최초 집회 일로 개시 다
# ② 이 헌법 공포 당시 국회의원 임기 제 1 항 의하다 국회 최초 집회 일 전일 하다
# 제 4조 ① 이 헌법 시행 당시 공무원 정부 임명 기업체 임원 이 헌법 의하다 임명 되다 것 보다 다만 이 헌법 의하다 선임 방법 임명 권 자가 변경 되다 공무원 대법원 장 및 감사원장 이 헌법 의하다 후임 자 선임 되다 때 그 직무 행 하다 이 경우 전 임자 공무원 임기 후임 자 선임 되다 전일 하다
# ② 이 헌법 시행 당시 대법원 장 대법원판사 아니다 법관 제 1 항 단서 규정 불구 이 헌법 의하다 임명 되다 것 보다
# ③ 이 헌법 중 공무원 임기 또는 중임 제한 관 규정 이 헌법 의하다 그 공무원 최초 선출 또는 임명 되다 때 로부터 적용 하다
# 제 5조 이 헌법 시행 당시 법령 조약 이 헌법 위배 되다 아니다 하다 그 효력 지속 다
# 제 6조 이 헌법 시행 당시 이 헌법 의하다 새롭다 설치 되다 기관 권한 속 하다 직무 행 있다 기관 이 헌법 의하다 새롭다 기관 설치 되다 때 존속 하다 그 직무 행 하다
#
# OK

# %% [markdown]
# kolwa.model 로 저장한 모델을 사용하자

# %%
model = word2vec.Word2Vec.load('data/kolaw.model')

# %% [markdown]
# 유사한 단어를 확인할 때 wv.most_similar()를 사용한다.

# %%
result = model.wv.most_similar(positive=['국민'])
result
# Out:
# [('의무', 0.9963914155960083),
#  ('모든', 0.9957342743873596),
#  ('정', 0.995196521282196),
#  ('개발', 0.9951783418655396),
#  ('보호', 0.9951227903366089),
#  ('직무', 0.9939312934875488),
#  ('필요하다', 0.9937732219696045),
#  ('및', 0.9935662746429443),
#  ('사항', 0.9934930205345154),
#  ('급', 0.9931744933128357)]
